# %% [markdown]
# <a href="https://colab.research.google.com/github/harshadikonda/2025-26_DS_AI-B_HARSHA_4109/blob/main/Data_manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Data Manipulation
import pandas as pd

#Create DataFrame
data={
    "Name":["A","B","C"],
    "Age":[21,22,23],
    "Marks":[70,80,90]
}

df=pd.DataFrame(data)

print("original Data:")
print(df)


#Add new column
df["Bonus"]=5
print("\nAfter adding Bonus:")
print(df)

#Increasing marks
df["Marks"]=df["Marks"]+2
print("\nAfter increasing marks:")
print(df)

#Change value
df.loc[0,"Age"]=21
print("\nAfter changing value:")
print(df)

#Rename column
df.rename(columns={"Total":"final"},inplace=True)
print("\n After renaming total to final:")
print(df)

#Remove column
df.drop("Bonus",axis=1,inplace=True)
print("\n After removing bonus:")
print(df)
# Out:
# original Data:
#   Name  Age  Marks
# 0    A   21     70
# 1    B   22     80
# 2    C   23     90
#
# After adding Bonus:
#   Name  Age  Marks  Bonus
# 0    A   21     70      5
# 1    B   22     80      5
# 2    C   23     90      5
#
# After increasing marks:
#   Name  Age  Marks  Bonus
# 0    A   21     72      5
# 1    B   22     82      5
# 2    C   23     92      5
#
# After changing value:
#   Name  Age  Marks  Bonus
# 0    A   21     72      5
# 1    B   22     82      5
# 2    C   23     92      5
#
#  After renaming total to final:
#   Name  Age  Marks  Bonus
# 0    A   21     72      5
# 1    B   22     82      5
# 2    C   23     92      5
#
#  After removing bonus:
#   Name  Age  Marks
# 0    A   21     72
# 1    B   22     82
# 2    C   23     92
