# %% [markdown]
# <a href="https://colab.research.google.com/github/harshadikonda/2025-26_DS_AI-B_HARSHA_4109/blob/main/sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

A.add(10)
A.update([7, 8])

A.remove(2)
A.discard(100)
A.pop()

print("Union:", A | B)
print("Intersection:", A & B)
print("Difference:", A - B)
print("Symmetric Difference:", A ^ B)

print("Union method:", A.union(B))
print("Intersection method:", A.intersection(B))
print("Difference method:", A.difference(B))

print(3 in A)
print(len(A))

print(A.issubset(B))
print(A.issuperset(B))

for i in A:
    print(i, end=" ")
# Out:
# Union: {3, 4, 5, 6, 7, 8, 10}
# Intersection: {3, 4}
# Difference: {8, 10, 7}
# Symmetric Difference: {5, 6, 7, 8, 10}
# Union method: {3, 4, 5, 6, 7, 8, 10}
# Intersection method: {3, 4}
# Difference method: {8, 10, 7}
# True
# 5
# False
# False
# 3 4 7 8 10
